# %%
#Using conda custom yolo enviorment

# %%
cd C:\Users\jacob\Desktop\Projects\ANPR_Camera\YOLOv5_Project
# Out:
# C:\Users\jacob\Desktop\Projects\ANPR_Camera\YOLOv5_Project

# %%
pwd
# Out:
# 'C:\\Users\\jacob\\Desktop\\Projects\\ANPR_Camera\\YOLOv5_Project'

# %%
# !python detect.py --weights yolov5s.pt --source C:\\Users\\jacob\\Desktop\\Projects\\ANPR_Camera\\Golf_GTI_2.mp4

# %%
# !python detect.py --weights yolov5s.pt --source C:\\Users\\jacob\\Desktop\\Projects\\ANPR_Camera\\Golf_GTI_2.mp4 --view-img
# Out:
# detect: weights=['yolov5s.pt'], source=C:\\Users\\jacob\\Desktop\\Projects\\ANPR_Camera\\Golf_GTI_2.mp4, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=True, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v7.0-314-g60dde7f1 Python-3.12.3 torch-2.3.0 CUDA:0 (NVIDIA GeForce RTX 3070, 8192MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# video 1/1 (1/228) C:\Users\jacob\Desktop\Projects\ANPR_Camera\Golf_GTI_2.mp4: 384x640 (no detections), 66.9ms
# video 1/1 (2/228) C:\Users\jacob\Desktop\Projects\ANPR_Camera\Golf_GTI_2.mp4: 384x640 (no detections), 8.0ms
# ...

# %%
# !python train.py --img 640 --batch 16 --epochs 100 --data C:\\Users\\jacob\\Desktop\\Projects\\ANPR_Camera\\data2.yaml --weights yolov5s.pt
