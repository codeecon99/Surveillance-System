# %%
from PIL import Image
import pytesseract

# %%
from PIL import Image
import pytesseract

# Load the image
image = Image.open('C:\\Users\\jacob\\Desktop\\Projects\\ANPR_Camera\\eurotext.png')

# Perform OCR
text = pytesseract.image_to_string(image)

# Print the extracted text
print(text)
# Out:
# The (quick) [brown] {fox} jumps!
# Over the $43,456.78 <lazy> #90 dog
# & duck/goose, as 12.5% of E-mail
# from aspammer@website.com is spam.
# Der ,,schnelle” braune Fuchs springt
# tiber den faulen Hund. Le renard brun
# «rapide» saute par-dessus le chien
# paresseux. La volpe marrone rapida
# salta sopra il cane pigro. El zorro
# marron rapido salta sobre el perro
# perezoso. A raposa marrom rapida
# salta sobre 0 cdo preguigoso.

# %%
import cv2
import numpy as np

# Load the image
#image = Image.open('C:\\Users\\jacob\\Desktop\\Projects\\ANPR_Camera\\YOLOv5_Project\\runs\\detect\\exp25\\crops\\license_plate\\Golf_GTI_243.jpg')
image = Image.open('C:\\Users\\jacob\\Desktop\\Projects\\ANPR_Camera\\eurotext.png')


# Convert PIL image to OpenCV format
image_cv = cv2.cvtColor(np.array(image), cv2.COLOR_RGB2BGR)

# Preprocessing: Apply binarization, noise removal, thresholding, etc.
# Example:
gray = cv2.cvtColor(image_cv, cv2.COLOR_BGR2GRAY)
binary = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)[1]

# Convert OpenCV image back to PIL format
preprocessed_image = Image.fromarray(binary)

# Perform OCR on the preprocessed image
text = pytesseract.image_to_string(preprocessed_image)

# Print the extracted text
print(text)
# Out:
# The (quick) (brown] {fox} jumps!
# Over the $43,456.78 <lazy> #90 dog
# & duck/goose, as 12.5% of E-mail
# from aspammer@website.com is spam.
# Der ,.schnelle” braune Fuchs springt
# tber den faulen Hund. Le renard brun
# «rapide» saute par-dessus le chien
# paresseux. La volpe marrone rapida
# salta sopra il cane pigro. El zorro
# marron rapido salta sobre el perro
# perezoso. A raposa marrom rapida
# salta sobre 0 c4o preguigoso.

# %%
# Load the original image
original_image = Image.open('C:\\Users\\jacob\\Desktop\\Projects\\ANPR_Camera\\YOLOv5_Project\\runs\\detect\\exp25\\crops\\license_plate\\Golf_GTI_243.jpg')

# Target size for resizing (maintain aspect ratio)
target_width = 200
target_height = 200

# Resize the image while preserving aspect ratio
#resized_image = original_image.resize((target_width, target_height))
resized_image = original_image.resize((100, 100), Image.BICUBIC)

# %%
# Perform OCR
text = pytesseract.image_to_string(resized_image)

# Print the extracted text
print(text)

# %%
# Convert PIL image to OpenCV format

image = resized_image


image_cv = cv2.cvtColor(np.array(image), cv2.COLOR_RGB2BGR)

# Preprocessing: Apply binarization, noise removal, thresholding, etc.
# Example:
gray = cv2.cvtColor(image_cv, cv2.COLOR_BGR2GRAY)
binary = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)[1]

# Convert OpenCV image back to PIL format
preprocessed_image = Image.fromarray(binary)

# Perform OCR on the preprocessed image
text = pytesseract.image_to_string(preprocessed_image)

# Print the extracted text
print(text)

# %%
upscaled_image = original_image.resize((100, 100), Image.BICUBIC)

# %%
upscaled_image
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
upscaled_image = original_image.resize((200, 200), Image.LANCZOS)
upscaled_image
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
upscaled_image = original_image.resize((100, 100), Image.NEAREST)
upscaled_image
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
from PIL import Image
c = Image.open('C:\\Users\\jacob\\Desktop\\Projects\\ANPR_Camera\\YOLOv5_Project\\runs\\detect\\exp25\\crops\\license_plate\\Golf_GTI_243.jpg')
d = c.resize((200,200), resample=Image.BOX)

# %%
d
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
text = pytesseract.image_to_string(d)

# Print the extracted text
print(text)

# %%
image = Image.open('C:\\Users\\jacob\\Desktop\\Projects\\ANPR_Camera\\TEST_CAR.png')

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=337x249>

# %%
# Perform OCR
text = pytesseract.image_to_string(image)

# Print the extracted text
print(text)

# %%
import cv2

# Load the small image
small_image = cv2.imread('C:\\Users\\jacob\\Desktop\\Projects\\ANPR_Camera\\YOLOv5_Project\\runs\\detect\\exp25\\crops\\license_plate\\Golf_GTI_243.jpg')

# Upscale the image using bicubic interpolation
upscaled_image = cv2.resize(small_image, (500, 500), interpolation=cv2.INTER_CUBIC)

# Save the upscaled image
cv2.imwrite('upscaled_image.jpg', upscaled_image)
# Out:
# True

# %%
upscaled_image = Image.open('upscaled_image.jpg')

# Perform OCR on the upscaled image
text = pytesseract.image_to_string(upscaled_image)

# Print the extracted text
print(text)

# %%
image = Image.open('C:\\Users\\jacob\\Desktop\\Projects\\ANPR_Camera\\TEST_PHOTOS\\DEMO_BMW.png')

# Perform OCR
text = pytesseract.image_to_string(image)

# Print the extracted text
print(text)

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=226x55>

# %%
img = cv2.imread("C:\\Users\\jacob\\Desktop\\Projects\\ANPR_Camera\\TEST_PHOTOS\\DEMO_BMW.png")

# Convert to the gray-scale
gry = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# OCR
print(pytesseract.image_to_string(gry, config="--psm 6"))

# Display
cv2.imshow("", gry)
cv2.waitKey(0)
# Out:
# SLA® VEKM3
# -1

# %%
# Read the license plate file and display it 
#test_license_plate = Image.open('C:\\Users\\jacob\\Desktop\\Projects\\ANPR_Camera\\TEST_PHOTOS\\DEMO_BMW.png')
#test_license_plate = cv2.imread("C:\\Users\\jacob\\Desktop\\Projects\\ANPR_Camera\\TEST_PHOTOS\\DEMO_BMW_3.jpg") 
test_license_plate = cv2.imread("C:\\Users\\jacob\\Desktop\\Projects\\ANPR_Camera\\YOLOv5_Project\\runs\\detect\\exp25\\crops\\license_plate\\Golf_GTI_243.jpg") 

plt.imshow(test_license_plate) 
plt.axis('off') 
plt.title('GWT2180 license plate')
# Out:
# Text(0.5, 1.0, 'GWT2180 license plate')

# %%
resize_test_license_plate = cv2.resize( test_license_plate, None, fx = 2, fy = 2,interpolation = cv2.INTER_CUBIC)

# %%
grayscale_resize_test_license_plate = cv2.cvtColor(resize_test_license_plate, cv2.COLOR_BGR2GRAY)

# %%
gaussian_blur_license_plate = cv2.GaussianBlur(grayscale_resize_test_license_plate, (5, 5), 0)

# %%
new_predicted_result_GWT2180 = pytesseract.image_to_string(gaussian_blur_license_plate, lang ='eng', 
config="--oem 3 --psm 6 -c tessedit_char_whitelist=ABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789") 
filter_new_predicted_result_GWT2180 = "".join(new_predicted_result_GWT2180.split()).replace(":", "").replace("-", "") 
print(filter_new_predicted_result_GWT2180)
# Out:
# 817
